# %%
import numpy as np
from numpy import pi
import h5py
from matplotlib import pyplot as plt
from qutip  import *
import qutip as qt
from scipy.optimize import curve_fit

# %%
def H_CPT(N,del_c, del_p, Omega_c, Omega_p, chi,kappa,Gamma,dephase):
    # Hamiltonian form is given by equation 7.3 from Novokov's thesis
    
    # del_x: detuning from the transitions
    # Omega_x: Rabi frequency for each transitions
    # chi is the dispersive shift, and note that the cavity freq difference when qubit is at |e> or |g> is 2*chi  
    # Qubit subspace: 2x2, Cavity subspace: N+1 x N+1
    g =basis(2,0)
    e = basis(2,1)
    
    term1 = -(del_c+2*chi)*tensor(g*g.dag(),num(N+1))
    term2 = -del_p*tensor(e*e.dag() ,qeye(N+1))-del_c *(tensor(e*e.dag(),num(N+1))-tensor(e*e.dag(),qeye(N+1)))
    term3 = (Omega_c/2)*tensor(e*e.dag(),create(N+1))
    term4 = qt.tensor(qt.basis(2,1), qt.basis(N+1,1))*(tensor(qt.basis(2,0), qt.basis(N+1,0)).dag()) * Omega_p/2
    H = term1 + term2 + term3 + term4 + (term3+term4).dag() 
    
    A_cav   = tensor(qeye(2),destroy(N+1))*np.sqrt(kappa)
    A_relax   = tensor(destroy(2),qeye(N+1))*np.sqrt(Gamma)
    A_dephase = tensor(sigmaz(), qeye(N+1)) * np.sqrt(dephase)
    return H,[A_cav,A_relax,A_dephase]

# %%
def CPT_Spectrum(N,del_list, Omega_c, Omega_p):
    del_control=0
    chi = -1.1* (2*np.pi) #dispersive shift
    kappa = 7.9333
    Gamma = 0.115 #T1=10us  T2=5us dephase = 1/(5e-6)-1/2*(10e-6)
    dephase =0.012#0.230.012
    control="hi"
    spec = np.zeros(len( del_list), dtype=np.float64)
    spec_real = np.zeros(len( del_list), dtype=np.float64)
    spec_imag = np.zeros(len( del_list), dtype=np.float64)
    pop_g0 = np.zeros(len( del_list), dtype=np.float64)
    pop_e0 = np.zeros(len( del_list), dtype=np.float64)
    pop_e1 = np.zeros(len( del_list), dtype=np.float64)
    
    def spectrum(H, c_ops):
        rho_ss= steadystate(H, c_ops,solver='scipy')
        spec = rho_ss[N+1, (N+2)].imag
        pop_g0 = rho_ss[0, 0].real
        pop_e0 =expect(num(2) ,ptrace(rho_ss,0))#rho_ss[N+1, (N+1)].real
        pop_e1 =rho_ss[N+2, N+2].real
        return spec, pop_g0, pop_e0, pop_e1
    if control=="Probe":
        for i, del_c in enumerate(del_list):
            H ,c_ops = H_CPT(N,del_c,del_control, Omega_c, Omega_p, chi,kappa,Gamma,dephase)
            spec[i], pop_g0[i], pop_e0[i], pop_e1[i] = spectrum(H ,c_ops)
    
    else:
        for i, del_p in enumerate(del_list):
            H ,c_ops = H_CPT(N,del_control,del_p, Omega_c, Omega_p, chi,kappa,Gamma,dephase)
            spec[i], pop_g0[i], pop_e0[i], pop_e1[i] = spectrum(H ,c_ops)
            
    return pop_e0#,spec,pop_g0,pop_e1

# %%
def func(x,a,b,c,d,t1):
    return a * np.cos(b*(x-c)) * np.exp(-(x-c)/t1) + d

directory = 'C:\\Users\\user\\SynologyDrive\\DESKTOP-V6JLHQU\\C\\Users\\cluster\\Labber\\Data\\2022\\08\\Data_0817'
fname = '3Dtransmon002_rabi_007.hdf5'
path = directory + '\\' + fname

# Read data and plot
with h5py.File(path,'r') as hf:
    #print ('Keys of this file: \n', list(hf.keys()))
    #print (list(data_group.keys()))
    data = hf['Data/Data']
    # Initializer,RF_Qubit
    #power = hf['Step config/Initializer - Power/Step items'][0][2]
    #fd    = hf['Step config/Initializer - Frequency/Step items'][0][2]
    power = hf['Step config/RF_Qubit - Power/Step items'][0][2]
    fd    = hf['Step config/RF_Qubit - Frequency/Step items'][0][2]
    # Check logger comment for time duration
    N = data.shape[0]
    """ INPUT dt """
    #dt = 8
    #time = np.linspace(0, (N-1) * dt, N)
    time = data[:,0,0]*1e+9
    dt = (time[1]-time[0])
    
    # Extract I, Q data
    demod_real = data[:,1,0]
    demod_imag = data[:,2,0]
    demod_mag = np.abs(demod_real + 1j*demod_imag) * 1e+6

fitted = demod_mag/1000
ground = max(fitted)
excite = min(fitted)
time_nice = np.linspace(time[0], time[-1], 201)
label = "Ground {:.3f} mV".format(max(fitted))+"\nexcite = {:.3f} mV".format(min(fitted))
plt.plot(time, fitted , 'r.-', alpha = 0.5,label = label)

plt.title(fname)
plt.xlabel('ns')
plt.ylabel('$mag (m v)$')
plt.legend()
plt.show()

# %%
directory = 'C:\\Users\\user\\SynologyDrive\\DESKTOP-V6JLHQU\\C\\Users\\cluster\\Labber\\Data\\2022\\08\\Data_0817'
fname = '3Dtransmon002_CPT_fix_couple_population_008.hdf5'
path = directory + '\\' + fname
idx=3

with h5py.File(path,'r') as hf:
    #print(hf.keys())
    raw_data = np.copy(hf["Data"]["Data"])
    print("data shape:", raw_data.shape)
    
resonace=5307.4

e_pop = np.zeros((12,573))
for i in range(12):
    freq = raw_data[:,0,i] * 1e-6
    Data = raw_data[:,2,i] + 1j*raw_data[:,3,i]
    mag  = np.abs(Data) * 1e+3 
    e_pop[i]=(ground-mag)/(ground-excite)

extent = -40, 40, -45, -34
plt.figure(figsize=(10,6))
plt.imshow(e_pop, origin="lower", aspect = "auto", cmap = "RdBu_r", interpolation = "None", extent=extent) 
plt.xlabel(r"$\Delta_p$ (MHz)",fontsize=15)
plt.ylabel("Probe power(dBm)",fontsize=15)
plt.colorbar()
# Out:
# data shape: (573, 4, 12)

# %%
directory = 'C:\\Users\\user\\SynologyDrive\\DESKTOP-V6JLHQU\\C\\Users\\cluster\\Labber\\Data\\2022\\08\\Data_0817'
fname = '3Dtransmon002_CPT_fix_couple_population_008.hdf5'
path = directory + '\\' + fname
idx=3

with h5py.File(path,'r') as hf:
    #print(hf.keys())
    raw_data = np.copy(hf["Data"]["Data"])
    print("data shape:", raw_data.shape)
    
resonace=5307.4

e_pop = np.zeros((8,573))
for i in range(8):
    freq = raw_data[:,0,i] * 1e-6
    Data = raw_data[:,2,i] + 1j*raw_data[:,3,i]
    mag  = np.abs(Data) * 1e+3 
    e_pop[i]=(ground-mag)/(ground-excite)

extent = -40, 40, 3.3, 6
plt.figure(figsize=(10,6))
plt.imshow(e_pop, origin="lower", aspect = "auto", cmap = "RdBu_r", interpolation = "None", extent=extent) 
plt.xlabel(r"$\Delta_c/2\pi$ (MHz)",fontsize=20)
plt.ylabel(r"$\Omega_p/2\pi$ (MHz)",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.colorbar(label=r"$P_e$")
# Out:
# data shape: (573, 4, 12)

# %%
Omega_c = 3.3* (2*np.pi)  #3.4
Omega_p = 3.5* (2*np.pi)#3.8
N=13

#T1=10us  T2=5us dephase = 1/(5e-6)-1/2*(10e-6)
plt.figure(figsize=(11.35,7.79))
plt.plot(2*(freq-5307.4),e_pop[0],"-o",color="blue", markersize=6,label="exp",alpha=0.8)
del_list = 2*pi*2*(freq-5307.4)#2*pi*np.linspace(start, end, point)


z = np.zeros(573)
z= CPT_Spectrum(N,del_list, Omega_c, Omega_p)
plt.plot(del_list/(2*pi), z,"red" ,linewidth=5,label="theory",alpha=0.6)


plt.xlabel(r"$\Delta_p/2\pi$ (MHz)",fontsize=25)
plt.ylabel(r"$P_e$",fontsize=25)
plt.title("$\Omega_c$={:.1f} MHz".format(Omega_p/(2*np.pi))+\
            ",  $\Omega_p$ ={:.1f} MHz".format(Omega_c/(2*np.pi)),fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()

# %%
directory = 'C:\\Users\\user\\SynologyDrive\\DESKTOP-V6JLHQU\\C\\Users\\cluster\\Labber\\Data\\2022\\08\\Data_0817'
fname = '3Dtransmon002_CPT_fix_couple_population_008.hdf5'
path = directory + '\\' + fname
idx=3

with h5py.File(path,'r') as hf:
    #print(hf.keys())
    raw_data = np.copy(hf["Data"]["Data"])
    print("data shape:", raw_data.shape)
    
resonace=5307.4

e_pop = np.zeros((8,573))
for i in range(8):
    freq = raw_data[:,0,i] * 1e-6
    Data = raw_data[:,2,i] + 1j*raw_data[:,3,i]
    mag  = np.abs(Data) * 1e+3 
    e_pop[i]=(ground-mag)/(ground-excite)

extent = -20, 20, 3.3, 6
plt.figure(figsize=(10,6))
plt.imshow(e_pop, origin="lower", aspect = "auto", cmap = "RdBu_r", interpolation = "None", extent=extent) 
plt.xlabel(r"$\Delta_c/2\pi$ (MHz)",fontsize=20)
plt.ylabel(r"$\Omega_p/2\pi$ (MHz)",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.colorbar(label=r"$P_e$")
# Out:
# data shape: (573, 4, 12)

# %%
Omega_c = 2* (2*np.pi)  #3.4
Omega_p = 2.2* (2*np.pi)#3.8
N=13

#T1=10us  T2=5us dephase = 1/(5e-6)-1/2*(10e-6)
plt.figure(figsize=(11.35,7.79))
plt.plot((freq-5307.4),e_pop[0],"-o",color="blue", markersize=6,label="exp",alpha=0.8)
del_list = 2*pi*(freq-5307.4)#2*pi*np.linspace(start, end, point)


z = np.zeros(573)
z= CPT_Spectrum(N,del_list, Omega_c, Omega_p)
plt.plot(del_list/(2*pi), z,"red" ,linewidth=5,label="theory",alpha=0.6)


plt.xlabel(r"$\Delta_p/2\pi$ (MHz)",fontsize=25)
plt.ylabel(r"$P_e$",fontsize=25)
plt.title("$\Omega_c$={:.1f} MHz".format(Omega_p/(2*np.pi))+\
            ",  $\Omega_p$ ={:.1f} MHz".format(Omega_c/(2*np.pi)),fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend()

# %%
guess = [3.5* (2*np.pi), 
         3.4* (2*np.pi)]
qopt, qcov = curve_fit(CPT_Spectrum, del_list, e_pop[5], guess) 
plt.plot(del_list/(2*pi), CPT_Spectrum(del_list, qopt[0],qopt[1]))
plt.plot(2*(freq-5307.4),e_pop[0])
(qopt[0]/(2*np.pi),qopt[1]/(2*np.pi))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-9af9a559d94e> in <module>
#       1 guess = [3.5* (2*np.pi),
#       2          3.4* (2*np.pi)]
# ----> 3 qopt, qcov = curve_fit(CPT_Spectrum, del_list, e_pop[5], guess)
#       4 plt.plot(del_list/(2*pi), CPT_Spectrum(del_list, qopt[0],qopt[1]))
#       5 plt.plot(2*(freq-5307.4),e_pop[0])
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     782         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     783         return_full = kwargs.pop('full_output', False)
# --> 784         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     785         popt, pcov, infodict, errmsg, ier = res
#     786         ysize = len(infodict['fvec'])
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     420         if maxfev == 0:
#     421             maxfev = 200*(n + 1)
# --> 422         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     423                                  gtol, maxfev, epsfcn, factor, diag)
#     424     else:
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in func_wrapped(params)
#     482     if transform is None:
#     483         def func_wrapped(params):
# --> 484             return func(xdata, *params) - ydata
#     485     elif transform.ndim == 1:
#     486         def func_wrapped(params):
#
# <ipython-input-19-809c60b6432d> in CPT_Spectrum(del_list, Omega_c, Omega_p)
#      29         for i, del_p in enumerate(del_list):
#      30             H ,c_ops = H_CPT(del_control,del_p, Omega_c, Omega_p, chi,kappa,Gamma,dephase)
# ---> 31             spec[i], pop_g0[i], pop_e0[i], pop_e1[i] = spectrum(H ,c_ops)
#      32
#      33     return pop_e0#,spec,pop_g0,pop_e1
#
# <ipython-input-19-809c60b6432d> in spectrum(H, c_ops)
#      15
#      16     def spectrum(H, c_ops):
# ---> 17         rho_ss= steadystate(H, c_ops,solver='scipy')
#      18         spec = rho_ss[N+1, (N+2)].imag
#      19         pop_g0 = rho_ss[0, 0].real
#
# ~\anaconda3\lib\site-packages\qutip\steadystate.py in steadystate(A, c_op_list, method, solver, **kwargs)
#     309         if (ss_args['solver'] == 'scipy' and ss_args['sparse']) \
#     310                 or ss_args['solver'] == 'mkl':
# --> 311             return _steadystate_direct_sparse(A, ss_args)
#     312         else:
#     313             return _steadystate_direct_dense(A, ss_args)
#
# ~\anaconda3\lib\site-packages\qutip\steadystate.py in _steadystate_direct_sparse(L, ss_args)
#     454         orig_nnz = L.nnz
#     455         _direct_start = time.time()
# --> 456         lu = splu(L, permc_spec=ss_args['permc_spec'],
#     457                   diag_pivot_thresh=ss_args['diag_pivot_thresh'],
#     458                   options=dict(ILU_MILU=ss_args['ILU_MILU']))
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     335         _options["SymmetricMode"] = True
#     336
# --> 337     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
#     338                           csc_construct_func=csc_construct_func,
#     339                           ilu=False, options=_options)
#
# KeyboardInterrupt:

# %%
guess = [2* (2*np.pi), 
         3.4* (2*np.pi)]
qopt, qcov = curve_fit(CPT_Spectrum, del_list, e_pop[5], guess) 
plt.plot(del_list/(2*pi), CPT_Spectrum(del_list, qopt[0],qopt[1]))
plt.plot(2*(freq-5307.4),e_pop[0])
(qopt[0]/(2*np.pi),qopt[1]/(2*np.pi))
# Out:
# (5.39104461454509, 3.269536769114966)

# %%
guess = [3.5* (2*np.pi), 
         3.4* (2*np.pi)]
qopt, qcov = curve_fit(CPT_Spectrum, del_list, e_pop[9], guess) 
plt.plot(del_list/(2*pi), CPT_Spectrum(del_list, qopt[0],qopt[1]))
plt.plot(2*(freq-5307.4),e_pop[9])
(qopt[0]/(2*np.pi),qopt[1]/(2*np.pi))
# Out:
# (11.98208393181896, 7.1469792274073125)
